# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

#matplotlib.__version__

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig,ax=plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
#plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.with Matplotlib functions
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
plt.xlim("Jan", "June")
# Out:
# (0.0, 1.0)

# %%
plt.subplots(figsize=(20, 10))
# Out:
# (<Figure size 1440x720 with 1 Axes>, <AxesSubplot:>)

# %%
#Skill drill  # Create the plot.with MatPlotlib OOP functions
#Using the object-oriented approach, make the following changes to your line chart:

#Change the line color to green.
#Change the marker to a diamond.
#Change the line width to 2 points.
#Add a legend for the city of Boston.
#Add a title and axes labels.
#Add a y-axis limit.
#Add grid lines.

# Create the plot.with MatPlotlib OOP functions
fig, ax = plt.subplots(figsize=(10,10))
# Create labels for the x and y axes.
ax.plot(x_axis, y_axis, color="green",marker='D', label='Bostan',linewidth="2")
#ax.plot(x_axis, y_axis, )
#ax.plot()
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')
ax.legend('Boston')

# Set the y limit between 0 and 45.

ax.set_ylim(0, 45)

# Create a title.
ax.set_title("PyBer Fare for month")

# Add a grid.
ax.grid()

# Add the legend.

ax.legend()

# %%
#How to create bar charts with Matplotlib using the MATLAB method.

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
#Create a Vertical Bar Chart

# %%
#create the plot
plt.bar(x_axis,y_axis,color="green",linewidth="2",label="Bostan")
#create labels
plt.xlabel("Date")
plt.ylabel("Fare($)")
#create Title
plt.title("Pyber Fares for months")
#add legend
plt.legend()

# %%
#Create a Horizontal Bar Chart
plt.barh(x_axis,y_axis,color="magenta",label="Bostan")
plt.gca().invert_yaxis()
#If you want the data on opposite axes, switch the arguments in the barh() function and run the cell again:
#plt.barh(y_axis,x_axis,color="pink",label="Bostan")
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
#using the object-oriented approach. So let's learn how to do that now!

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
fig,ax=plt.subplots()
ax.bar(x_axis,y_axis,color="black",label="New York")
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')
ax.set_ylim(0,45)
ax.legend()

# %%
#Skill Drill
#Using the object-oriented approach, make the following changes:

#Change the bar color to cyan.

#Add a legend for the city of Chicago.

#Add a title and axes labels.

#Switch the axis so that the Fare($) data is on the x-axis.

#Invert the y-axis data.

fig,ax=plt.subplots()
ax.barh(x_axis,y_axis,color="cyan",label='Chicago')
ax.invert_yaxis()
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.legend()

# %%
#Create a Scatter Plot Using the MATLAB Method

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

#When we use the plt.plot() function to create a scatter plot, 
#we need to add a lowercase "o" as a parameter inside the parentheses.
#This switches the plot from a line chart to a scatter plot.
plt.plot(x_axis,y_axis,'o')
#plt.scatter()

# %%
#Using the Matplotlib MATLAB plotting approach, make the following changes to your scatter plot:

#Change the color of the markers to red.
plt.scatter(y_axis,x_axis,color="r",label="Chicago")
#Add a legend for the city of Chicago.

#Add a title and axes labels.

#plt.xlabel("Date")
#plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()
#Switch the axis so that the Fare($) data is on the x-axis.
plt.ylabel("Date")
plt.xlabel("Fare($)")
#Add a limit for the x-axis data.
plt.xlim(45,5)
#Invert the y-axis so that January is at the top.

plt.gca().invert_xaxis()

# %%
#plt.scatter(x_axis, y_axis,s=y_axis)
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#Create a Scatter Plot Using the Object-Oriented Interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#SkillDrill 5.1.7#Create a Bubble Chart Using the Object-Oriented Interface
#Using the object-oriented approach, make the following changes to your bubble chart:

#Change the color of the markers to sky blue.

#Change the size of the markers to 5 times each data point.

#Make the color 20% transparent.

#Add a black edge color to the circles.

#Make the linewidth of the circles 2 points.

#Add a legend for the city of Boston.

#Add a title.

#Switch the axis so that the Fare($) data is on the x-axis.

#Add a limit for the x-axis data.

#Invert the y-axis so that January is at the top.
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis,s = [i * 3 for i in y_axis], color="skyblue",alpha=0.8,edgecolors="black",linewidth=2,label='Bostan' )
ax.legend()
ax.set_title("PyBer Fare by Month")
ax.set_xlim()
ax.invert_yaxis()
plt.show()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1da8bd01888>,
#   <matplotlib.patches.Wedge at 0x1da8bcb5388>,
#   <matplotlib.patches.Wedge at 0x1da8bca9f88>,
#   <matplotlib.patches.Wedge at 0x1da8bc01bc8>,
#   <matplotlib.patches.Wedge at 0x1da8bc8f408>,
#   <matplotlib.patches.Wedge at 0x1da8bb6c788>,
#   <matplotlib.patches.Wedge at 0x1da8bc98588>,
#   <matplotlib.patches.Wedge at 0x1da8bcce708>,
#   <matplotlib.patches.Wedge at 0x1da8bc8f048>,
#   <matplotlib.patches.Wedge at 0x1da8bc40308>,
#   <matplotlib.patches.Wedge at 0x1da8bd011c8>,
#   <matplotlib.patches.Wedge at 0x1da8b876b48>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig,ax=plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Skill Drill Using the object-oriented approach, make the following changes to the pie chart:

fig, ax = plt.subplots(figsize=(10,10))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)


ax.pie(y_axis,
       labels=x_axis,
       explode=explode_values,
       autopct='%.1f%%',
       shadow=True,
       startangle=90,
       counterclock=False,
      colors=colors)
plt.show()
#Add a percentage to one decimal place to each wedge of the pie.

#Increase the figure size to 8x8.

#Explode the two highest percentage months.

#Add a shadow.

#Add a start angle so that January is at the top.

#Reverse the order so that the month order is in a clockwise direction.

#Add new colors of your own choosing or use the colors from the previous pie chart.
